# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def circle(n_res):
    line = np.array([i/n * 2*np.pi for i in range(n+1)])
    
    X, Y = np.cos(line), np.sin(line)
    return(X,Y)

# %%
n = 16
X, Y = circle(n)

# %%
plt.figure(figsize = (6,6))
plt.plot(X,Y)
plt.show()
